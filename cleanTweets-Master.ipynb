# %%
#do all the imports

import pandas as pd
import glob
import json
import numpy as np
import pandas as pd
import csv
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
os.getcwd()  #just checking what directory we are workign in
# Out:
# 'C:\\Users\\patti\\LearnPython\\prideProject'

# %%
#read in the CSV of tweets 
df=pd.read_csv("tweet_df.csv")

# %%
# initial data cleaning


df = df.replace({'\n': ' '}, regex=True) # remove linebreaks in the dataframe
df = df.replace({'\t': ' '}, regex=True) # remove tabs in the dataframe
df = df.replace({'\r': ' '}, regex=True) # remove carriage return in the dataframe
df.rename(columns={'text':'tweet', 'compound':'compound_score'}, inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   ID          datetime has_media  \
# 0           0             0  1004467998592190000    6/6/2018 17:00       NaN
# 1           1             1  1014169422544580000    7/3/2018 11:30       NaN
# 2           2             2  1015540312406670000     7/7/2018 6:17      True
# 3           3             3  1020145195621330000   7/19/2018 23:15       NaN
# 4           4             4  1052967828909940000  10/18/2018 13:01       NaN
#
#    is_reply  is_retweet                       medias  nbr_favorite  nbr_reply  \
# 0     False       False                          NaN             2          0
# 1     False       False                          NaN            34          2
# 2     False       False  ['https://t.co/1onwI19FwF']             1          0
# 3     False       False                          NaN             9          2
# 4     False       False                          NaN           488         16
#
#    nbr_retweet                                              tweet  \
# 0            0  Hey @Angels  we are waiting...signed your loya...
# 1            5  OMG @ANGELS  YESSSSS! Finally doing the thing....
# 2            0  27-time #WorldSeries  Champions #NewYork  @Yan...
# 3            1  Are you a woman? Do you like @Angels  baseball...
# 4           90  We're proud to join @MLB  in taking a stand ag...
#
#                                           url    user_id   usernameTweet  \
# 0  /AarontheBaaron/status/1004467998592196614   26010109  AarontheBaaron
# 1   /OhItsRicardo_/status/1014169422544580608   19224173   OhItsRicardo_
# 2    /newstruthliz/status/1015540312406675462  377904401    newstruthliz
# 3   /OhItsRicardo_/status/1020145195621339137   19224173   OhItsRicardo_
# 4          /Angels/status/1052967828909944832   39392910          Angels
#
#      team
# 0  angels
# 1  angels
# 2  angels
# 3  angels
# 4  angels

# %%
#build a process that does basic data cleaning; we will use it later
import re
def process_tweet(tweet):
    return " ".join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])", "",tweet.lower()).split())

# %%
#initialize the Vader library

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
#create the analyzer function

def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
#test the analyzer using a random sentence we input

sentiment_analyzer_scores("This game is really dumb.")
# Out:
# This game is really dumb.--------------- {'neg': 0.473, 'neu': 0.527, 'pos': 0.0, 'compound': -0.5563}

# %%
sentiment_analyzer_scores("I don't like either of these teams and I wish they could both lose.")
# Out:
# I don't like either of these teams and I wish they could both lose. {'neg': 0.291, 'neu': 0.545, 'pos': 0.164, 'compound': -0.2755}

# %%
#begin the sentiment analysis by calling the analyzer, creating an empty list, and looping through the df to analyze the tweet row

sid = SentimentIntensityAnalyzer()


listy = []

for index, row in df.iterrows():
  ss = sid.polarity_scores(row["tweet"])
  listy.append(ss)

se = pd.Series(listy)
df['polarity'] = se.values

display(df.head(10))
# Out:
#    Unnamed: 0  Unnamed: 0.1                   ID          datetime has_media  \
# 0           0             0  1004467998592190000    6/6/2018 17:00       NaN
# 1           1             1  1014169422544580000    7/3/2018 11:30       NaN
# 2           2             2  1015540312406670000     7/7/2018 6:17      True
# 3           3             3  1020145195621330000   7/19/2018 23:15       NaN
# 4           4             4  1052967828909940000  10/18/2018 13:01       NaN
# 5           5             5  1052987037735770000  10/18/2018 14:17       NaN
# 6           6             6  1053043222816210000  10/18/2018 18:00       NaN
# 7           7             7  1053059492601040000  10/18/2018 19:05       NaN
# 8           8             8  1053062388319160000  10/18/2018 19:16       NaN
# 9           9             9  1053995842296780000   10/21/2018 9:06       NaN
#
#    is_reply  is_retweet                       medias  nbr_favorite  nbr_reply  \
# 0     False       False                          NaN             2          0
# 1     False       False                          NaN            34          2
# 2     False       False  ['https://t.co/1onwI19FwF']             1          0
# 3     False       False                          NaN             9          2
# 4     False       False                          NaN           488         16
# 5      True       False                          NaN             0          0
# 6     False       False                          NaN             5          2
# 7      True       False                          NaN             1          1
# 8      True       False                          NaN             1          0
# 9      True       False                          NaN             0          1
#
#    nbr_retweet                                              tweet  \
# 0            0  Hey @Angels  we are waiting...signed your loya...
# 1            5  OMG @ANGELS  YESSSSS! Finally doing the thing....
# 2            0  27-time #WorldSeries  Champions #NewYork  @Yan...
# 3            1  Are you a woman? Do you like @Angels  baseball...
# 4           90  We're proud to join @MLB  in taking a stand ag...
# 5            0  # Angels  social media representative LITERALL...
# 6            5  Noticed the @Nationals  didn't mention " LGBTQ...
# 7            0  To quote @larrywilmore , "saying the word gay ...
# 8            2  The Red Sox are what I'd call tier 1A. They QT...
# 9            0  Huh?   LGBTQ  youth? Where are the parents?  W...
#
#                                            url             user_id  \
# 0   /AarontheBaaron/status/1004467998592196614            26010109
# 1    /OhItsRicardo_/status/1014169422544580608            19224173
# 2     /newstruthliz/status/1015540312406675462           377904401
# 3    /OhItsRicardo_/status/1020145195621339137            19224173
# 4           /Angels/status/1052967828909944832            39392910
# 5     /Anonymous583/status/1052987037735776256           269670945
# 6  /queerfancystats/status/1053043222816219136  736744852080054000
# 7      /flautista21/status/1053059492601044993            49806394
# 8  /queerfancystats/status/1053062388319162371  736744852080054000
# 9          /RAROTH2/status/1053995842296782848          2329137653
#
#      usernameTweet    team                                           polarity
# 0   AarontheBaaron  angels  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 1    OhItsRicardo_  angels  {'neg': 0.0, 'neu': 0.832, 'pos': 0.168, 'comp...
# 2     newstruthliz  angels  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...
# 3    OhItsRicardo_  angels  {'neg': 0.055, 'neu': 0.571, 'pos': 0.374, 'co...
# 4           Angels  angels  {'neg': 0.148, 'neu': 0.53, 'pos': 0.322, 'com...
# 5     Anonymous583  angels  {'neg': 0.24, 'neu': 0.693, 'pos': 0.067, 'com...
# 6  queerfancystats  angels  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7      flautista21  angels  {'neg': 0.115, 'neu': 0.755, 'pos': 0.13, 'com...
# 8  queerfancystats  angels  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9          RAROTH2  angels  {'neg': 0.235, 'neu': 0.577, 'pos': 0.188, 'co...

# %%
#keeping this syntax in case we need it for anything later 
#but it actually prevents the split-and-merge technique (used a bit later) from working
#that's because that technique works only on a list, and taking out the braces makes it not be a list any more

#strip off the last character } since it breaks the splitter
#df['polarity'] = df['polarity'].map(lambda x: str(x)[:-1])

# %%
#df.polarity.apply(pd.Series) #just doing this to check that it works and actually splits the columns like we want
#keeping the syntax but commenting it out for now, as running it makes the notebook really long

# %%
#create a series from the list within the polarity column and append the series to the main dataframe
#basically we're splitting the polarity column and putting its components into 3 other columns


df2=df.polarity.apply(pd.Series) \
    .merge(df, left_index = True, right_index = True)

# %%
df2.head()
# Out:
#      neg    neu    pos  compound  Unnamed: 0  Unnamed: 0.1  \
# 0  0.000  0.780  0.220    0.4767           0             0
# 1  0.000  0.832  0.168    0.8585           1             1
# 2  0.000  0.901  0.099    0.5267           2             2
# 3  0.055  0.571  0.374    0.9399           3             3
# 4  0.148  0.530  0.322    0.5562           4             4
#
#                     ID          datetime has_media  is_reply  \
# 0  1004467998592190000    6/6/2018 17:00       NaN     False
# 1  1014169422544580000    7/3/2018 11:30       NaN     False
# 2  1015540312406670000     7/7/2018 6:17      True     False
# 3  1020145195621330000   7/19/2018 23:15       NaN     False
# 4  1052967828909940000  10/18/2018 13:01       NaN     False
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                         medias nbr_favorite  nbr_reply  nbr_retweet  \
# 0                          NaN            2          0            0
# 1                          NaN           34          2            5
# 2  ['https://t.co/1onwI19FwF']            1          0            0
# 3                          NaN            9          2            1
# 4                          NaN          488         16           90
#
#                                                tweet  \
# 0  Hey @Angels  we are waiting...signed your loya...
# 1  OMG @ANGELS  YESSSSS! Finally doing the thing....
# 2  27-time #WorldSeries  Champions #NewYork  @Yan...
# 3  Are you a woman? Do you like @Angels  baseball...
# 4  We're proud to join @MLB  in taking a stand ag...
#
#                                           url    user_id   usernameTweet  \
# 0  /AarontheBaaron/status/1004467998592196614   26010109  AarontheBaaron
# 1   /OhItsRicardo_/status/1014169422544580608   19224173   OhItsRicardo_
# 2    /newstruthliz/status/1015540312406675462  377904401    newstruthliz
# 3   /OhItsRicardo_/status/1020145195621339137   19224173   OhItsRicardo_
# 4          /Angels/status/1052967828909944832   39392910          Angels
#
#      team                                           polarity
# 0  angels  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 1  angels  {'neg': 0.0, 'neu': 0.832, 'pos': 0.168, 'comp...
# 2  angels  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...
# 3  angels  {'neg': 0.055, 'neu': 0.571, 'pos': 0.374, 'co...
# 4  angels  {'neg': 0.148, 'neu': 0.53, 'pos': 0.322, 'com...
#
# [5 rows x 21 columns]

# %%
df2.rename(columns={'text':'tweet', 'compound':'compound_score'}, inplace=True)
df2.head()
# Out:
#      neg    neu    pos  compound_score  Unnamed: 0  Unnamed: 0.1  \
# 0  0.000  0.780  0.220          0.4767           0             0
# 1  0.000  0.832  0.168          0.8585           1             1
# 2  0.000  0.901  0.099          0.5267           2             2
# 3  0.055  0.571  0.374          0.9399           3             3
# 4  0.148  0.530  0.322          0.5562           4             4
#
#                     ID          datetime has_media  is_reply  \
# 0  1004467998592190000    6/6/2018 17:00       NaN     False
# 1  1014169422544580000    7/3/2018 11:30       NaN     False
# 2  1015540312406670000     7/7/2018 6:17      True     False
# 3  1020145195621330000   7/19/2018 23:15       NaN     False
# 4  1052967828909940000  10/18/2018 13:01       NaN     False
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                         medias nbr_favorite  nbr_reply  nbr_retweet  \
# 0                          NaN            2          0            0
# 1                          NaN           34          2            5
# 2  ['https://t.co/1onwI19FwF']            1          0            0
# 3                          NaN            9          2            1
# 4                          NaN          488         16           90
#
#                                                tweet  \
# 0  Hey @Angels  we are waiting...signed your loya...
# 1  OMG @ANGELS  YESSSSS! Finally doing the thing....
# 2  27-time #WorldSeries  Champions #NewYork  @Yan...
# 3  Are you a woman? Do you like @Angels  baseball...
# 4  We're proud to join @MLB  in taking a stand ag...
#
#                                           url    user_id   usernameTweet  \
# 0  /AarontheBaaron/status/1004467998592196614   26010109  AarontheBaaron
# 1   /OhItsRicardo_/status/1014169422544580608   19224173   OhItsRicardo_
# 2    /newstruthliz/status/1015540312406675462  377904401    newstruthliz
# 3   /OhItsRicardo_/status/1020145195621339137   19224173   OhItsRicardo_
# 4          /Angels/status/1052967828909944832   39392910          Angels
#
#      team                                           polarity
# 0  angels  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 1  angels  {'neg': 0.0, 'neu': 0.832, 'pos': 0.168, 'comp...
# 2  angels  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...
# 3  angels  {'neg': 0.055, 'neu': 0.571, 'pos': 0.374, 'co...
# 4  angels  {'neg': 0.148, 'neu': 0.53, 'pos': 0.322, 'com...
#
# [5 rows x 21 columns]

# %%
df2.compound_score.unique()  #view the range of unique values in the compound_score, so we can make the right labels
# Out:
# array([ 0.4767,  0.8585,  0.5267, ..., -0.7668, -0.8957,  0.8449])

# %%
#define the process for marking the tweet score
#basically we are checking the value of the compound_score column and returning another value

def label_mark (row):
    
 
    if  row['compound_score']<=-0.6 :
        return '1'
   
    if  row['compound_score']<=-0.2 :
        return '2'
    if  row['compound_score']<=0.19 :
          return '3'
    if  row['compound_score']<=0.59 :
          return '4' 
       
    if  row['compound_score']>=0.591 :
          return '5'

  
    

#df = df[(df['closing_price']>=99 ) & (df['closing_price']<=101)]

# %%
#df2.apply (lambda row: label_mark(row), axis=1) #this is just to display what the labels will be, should we choose to assign them
#commenting it out, as running it makes the notebook really long

# %%
df2['tweet_grade'] = df2.apply (lambda row: label_mark(row), axis=1) #this assigns the labels into a new column

# %%
df2.tweet_grade.unique() #here we are checking to make sure there are no un-graded items and no unused values
# Out:
# array(['4', '5', '1', '3', '2'], dtype=object)

# %%
df2.to_csv('Pride_Graded_tweets_Part_2.csv', index=True)

# %%
#change some column formats

df2['datetime']= pd.to_datetime(df2['datetime']) 

df2['shortdate'] = df2['datetime'].dt.date
df2['shortdate'] = df2['shortdate'].astype(str)
df2['stringdate'] = df2['shortdate'].astype(str)


df2.head()
# Out:
#      neg    neu    pos  compound_score  Unnamed: 0  Unnamed: 0.1  \
# 0  0.000  0.780  0.220          0.4767           0             0
# 1  0.000  0.832  0.168          0.8585           1             1
# 2  0.000  0.901  0.099          0.5267           2             2
# 3  0.055  0.571  0.374          0.9399           3             3
# 4  0.148  0.530  0.322          0.5562           4             4
#
#                     ID            datetime has_media  is_reply     ...      \
# 0  1004467998592190000 2018-06-06 17:00:00       NaN     False     ...
# 1  1014169422544580000 2018-07-03 11:30:00       NaN     False     ...
# 2  1015540312406670000 2018-07-07 06:17:00      True     False     ...
# 3  1020145195621330000 2018-07-19 23:15:00       NaN     False     ...
# 4  1052967828909940000 2018-10-18 13:01:00       NaN     False     ...
#
#    nbr_retweet                                              tweet  \
# 0            0  Hey @Angels  we are waiting...signed your loya...
# 1            5  OMG @ANGELS  YESSSSS! Finally doing the thing....
# 2            0  27-time #WorldSeries  Champions #NewYork  @Yan...
# 3            1  Are you a woman? Do you like @Angels  baseball...
# 4           90  We're proud to join @MLB  in taking a stand ag...
#
#                                           url    user_id   usernameTweet  \
# 0  /AarontheBaaron/status/1004467998592196614   26010109  AarontheBaaron
# 1   /OhItsRicardo_/status/1014169422544580608   19224173   OhItsRicardo_
# 2    /newstruthliz/status/1015540312406675462  377904401    newstruthliz
# 3   /OhItsRicardo_/status/1020145195621339137   19224173   OhItsRicardo_
# 4          /Angels/status/1052967828909944832   39392910          Angels
#
#      team                                           polarity  tweet_grade  \
# 0  angels  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...            4
# 1  angels  {'neg': 0.0, 'neu': 0.832, 'pos': 0.168, 'comp...            5
# 2  angels  {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'comp...            4
# 3  angels  {'neg': 0.055, 'neu': 0.571, 'pos': 0.374, 'co...            5
# 4  angels  {'neg': 0.148, 'neu': 0.53, 'pos': 0.322, 'com...            4
#
#     shortdate  stringdate
# 0  2018-06-06  2018-06-06
# 1  2018-07-03  2018-07-03
# 2  2018-07-07  2018-07-07
# 3  2018-07-19  2018-07-19
# 4  2018-10-18  2018-10-18
#
# [5 rows x 24 columns]

# %%
#group and count the tweets

groups_df=pd.DataFrame(df2.groupby(['team', 'tweet_grade']).size().reset_index(name='tweet'))

# %%
groups_df.head()
# Out:
#      team tweet_grade  tweet
# 0  angels           1      5
# 1  angels           2     12
# 2  angels           3     39
# 3  angels           4     38
# 4  angels           5     47

# %%
groups_df.team.unique()
# Out:
# array(['angels', 'athletics', 'bluejays', 'braves', 'brewers',
#        'cardinals', 'cubs', 'dbacks', 'dodgers', 'giants', 'mariners',
#        'marlins', 'mets', 'mlb_general', 'nationals', 'padres',
#        'phillies', 'pirates', 'rays', 'reds', 'redsox', 'rockies',
#        'royals', 'tigers', 'twins', 'whitesox', 'yankees'], dtype=object)

# %%
#cleaning some stuff up in the datarame to make it easier to make a pretty plot
#dropping out the "mlb_general" grouping since it skews the numbers
#making a separate column based off of the tweet count, to make it easier to manipulate the bubble size
#put it all into a ne dataframe
groups_df2=groups_df[groups_df.team != 'mlb_general']
groups_df2['tweet_grade'] = pd.to_numeric(groups_df2['tweet_grade'])
groups_df2['bubble_size']= groups_df2.tweet*20
# Out:
# C:\Users\patti\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\patti\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
groups_df2.head()
# Out:
#      team  tweet_grade  tweet  bubble_size
# 0  angels            1      5          100
# 1  angels            2     12          240
# 2  angels            3     39          780
# 3  angels            4     38          760
# 4  angels            5     47          940

# %%
plt.figure(figsize=(9, 5))
ax = sns.scatterplot(x="team", y="tweet_grade",
                      hue="tweet", size='bubble_size',
                      palette="Accent",
                     data=groups_df2)
for item in ax.get_xticklabels():
    item.set_rotation(45)

# %%
#ax = sns.scatterplot(x="team", y="tweet_grade",s=("tweet"), data=groups_df)


#c = groups_df2['tweet_grade']
fig, ax = plt.subplots(facecolor='w',figsize=(14,10))
plt.xticks(rotation=70)

for key, row in groups_df2.iterrows():
    ax.scatter(row['team'], row['tweet_grade'], cmap = 'RdPu', s=row['tweet']*15,alpha=.5)
    
plt.title("Tweet Score Counts by Team")
plt.xlabel("Team")
plt.ylabel("Tweet Score")
# Out:
# Text(0, 0.5, 'Tweet Score')

# %%
#save the groups_df to a csv file

groups_df.to_csv("grouped_tweets_without_mlb.csv")

# %%
#reshape the data -this might help us plot it

reshaped_df=groups_df.pivot(index='team', columns='tweet_grade', values='tweet')
reshaped_df
# Out:
# tweet_grade     1      2      3      4      5
# team
# angels        5.0   12.0   39.0   38.0   47.0
# athletics     4.0   29.0  124.0  274.0  287.0
# bluejays      6.0   32.0   46.0  230.0  346.0
# braves       18.0   28.0   44.0   62.0  148.0
# brewers       8.0   12.0   30.0   81.0   73.0
# cardinals    20.0   33.0   48.0   87.0   95.0
# cubs         34.0   46.0  106.0   70.0  117.0
# dbacks        9.0   19.0   25.0   26.0   36.0
# dodgers      52.0   66.0   80.0  177.0  226.0
# giants       10.0   20.0   39.0   43.0   63.0
# mariners      6.0   44.0   76.0  201.0  250.0
# marlins      36.0   64.0   66.0   53.0   54.0
# mets         25.0   49.0  207.0  117.0  117.0
# mlb_general  59.0  117.0  211.0  637.0  747.0
# nationals    10.0   40.0  161.0  141.0  218.0
# padres       11.0   26.0   40.0   25.0   33.0
# phillies     23.0   46.0  208.0  158.0  155.0
# pirates      10.0   33.0  120.0   69.0  136.0
# rays         12.0   12.0   80.0   66.0  121.0
# reds          9.0   15.0   25.0   67.0   78.0
# redsox       21.0   37.0   49.0  110.0  108.0
# rockies      10.0   22.0   64.0   56.0   77.0
# royals        6.0   10.0   47.0   63.0   66.0
# tigers        8.0   13.0   16.0   50.0   94.0
# twins         NaN    2.0   14.0   26.0   45.0
# whitesox      4.0    9.0   31.0   34.0   36.0
# yankees       9.0   15.0   94.0   90.0   62.0

# %%
reshaped_df.reset_index(inplace=True)
reshaped_df.head()
# Out:
# tweet_grade       team     1     2      3      4      5
# 0               angels   5.0  12.0   39.0   38.0   47.0
# 1            athletics   4.0  29.0  124.0  274.0  287.0
# 2             bluejays   6.0  32.0   46.0  230.0  346.0
# 3               braves  18.0  28.0   44.0   62.0  148.0
# 4              brewers   8.0  12.0   30.0   81.0   73.0

# %%
reshaped_df.reset_index(drop=True)
reshaped_df.head()
# Out:
# tweet_grade       team     1     2      3      4      5
# 0               angels   5.0  12.0   39.0   38.0   47.0
# 1            athletics   4.0  29.0  124.0  274.0  287.0
# 2             bluejays   6.0  32.0   46.0  230.0  346.0
# 3               braves  18.0  28.0   44.0   62.0  148.0
# 4              brewers   8.0  12.0   30.0   81.0   73.0

# %%
df_counts=df2.groupby(['team','tweet_grade']).size().reset_index(name='counts')
df_counts
# Out:
#           team tweet_grade  counts
# 0       angels           1       5
# 1       angels           2      12
# 2       angels           3      39
# 3       angels           4      38
# 4       angels           5      47
# 5    athletics           1       4
# 6    athletics           2      29
# 7    athletics           3     124
# 8    athletics           4     274
# 9    athletics           5     287
# 10    bluejays           1       6
# 11    bluejays           2      32
# 12    bluejays           3      46
# 13    bluejays           4     230
# 14    bluejays           5     346
# 15      braves           1      18
# 16      braves           2      28
# 17      braves           3      44
# 18      braves           4      62
# 19      braves           5     148
# 20     brewers           1       8
# 21     brewers           2      12
# 22     brewers           3      30
# 23     brewers           4      81
# 24     brewers           5      73
# 25   cardinals           1      20
# 26   cardinals           2      33
# 27   cardinals           3      48
# 28   cardinals           4      87
# 29   cardinals           5      95
# ..         ...         ...     ...
# 104     redsox           5     108
# 105    rockies           1      10
# 106    rockies           2      22
# 107    rockies           3      64
# 108    rockies           4      56
# 109    rockies           5      77
# 110     royals           1       6
# 111     royals           2      10
# 112     royals           3      47
# 113     royals           4      63
# 114     royals           5      66
# 115     tigers           1       8
# 116     tigers           2      13
# 117     tigers           3      16
# 118     tigers           4      50
# 119     tigers           5      94
# 120      twins           2       2
# 121      twins           3      14
# 122      twins           4      26
# 123      twins           5      45
# 124   whitesox           1       4
# 125   whitesox           2       9
# 126   whitesox           3      31
# 127   whitesox           4      34
# 128   whitesox           5      36
# 129    yankees           1       9
# 130    yankees           2      15
# 131    yankees           3      94
# 132    yankees           4      90
# 133    yankees           5      62
#
# [134 rows x 3 columns]

# %%
#reference https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#4.-Jittering-with-stripplot

fig, ax = plt.subplots(figsize=(16,10), dpi= 40)
sns.stripplot(df_counts.team, df_counts.tweet_grade,size=df_counts.counts, ax=ax)


plt.title('Tweets by Grade and Team', fontsize=22)

plt.show()

# %%
reshaped_df_2=reshaped_df
reshaped_df_2.head()
# Out:
# tweet_grade       team     1     2      3      4      5
# 0               angels   5.0  12.0   39.0   38.0   47.0
# 1            athletics   4.0  29.0  124.0  274.0  287.0
# 2             bluejays   6.0  32.0   46.0  230.0  346.0
# 3               braves  18.0  28.0   44.0   62.0  148.0
# 4              brewers   8.0  12.0   30.0   81.0   73.0

# %%
colors = plt.cm.GnBu(np.linspace(0, 1, 10))

reshaped_df.plot(kind='bar', stacked=True, figsize=(20, 10), color=colors)

# %%
reshaped_df.columns
# Out:
# Index(['team', '1', '2', '3', '4', '5'], dtype='object', name='tweet_grade')

# %%
reshaped_df.set_index(["team"], inplace = True, 
                    append = True, drop = True)

# %%
#reshaped_df.columns = reshaped_df.columns.droplevel(0)
reshaped_df.head()
# Out:
# tweet_grade     1     2      3      4      5
#   team
# 0 angels      5.0  12.0   39.0   38.0   47.0
# 1 athletics   4.0  29.0  124.0  274.0  287.0
# 2 bluejays    6.0  32.0   46.0  230.0  346.0
# 3 braves     18.0  28.0   44.0   62.0  148.0
# 4 brewers     8.0  12.0   30.0   81.0   73.0

# %%
reshaped_df.to_csv("reshaped_grouped.csv")

# %%
#df=pd.read_csv("tweet_df.csv")
