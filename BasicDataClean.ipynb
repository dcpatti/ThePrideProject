# %%
#bring in the prerequisites

import pandas as pd
import glob
import json
import numpy as np
import pandas as pd

# %%
# identify the folder where the files are -- this will be done once per team, aligning the team folder name to the column we will create
files = glob.glob('raw_tweets/pride_whitesox/*')
#files = glob.glob('user/*')
len(files)
# Out:
# 192

# %%
#make a list to hold the files we are going to read
#then read the files into a dictionary

dictlist = []

for file in files:
    json_string = open(file, 'r').read()
    json_dict = json.loads(json_string)
    dictlist.append(json_dict)

# %%
#create a dataframe from the dictionary
df = pd.DataFrame(dictlist)
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1164182907981914113  2019-08-21 10:30:09       NaN     False       False
# 1  1164188556128071682  2019-08-21 10:52:36       NaN      True       False
# 2  1169382298984341504  2019-09-04 18:50:40       NaN     False       False
# 3  1169388554977533952  2019-09-04 19:15:32       NaN     False       False
# 4  1169393795416436736  2019-09-04 19:36:21       NaN     False       False
#
#   medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0    NaN           179         14           29
# 1    NaN            16          2            0
# 2    NaN             1          0            0
# 3    NaN             2          0            0
# 4    NaN             6          1            0
#
#                                                 text  \
# 0  Join us for  Pride  Night at #TheK  on Septemb...
# 1  So glad the @Royals  are finally promoting #Pr...
# 2  @ Royals   Pride  Night at The K #kcroyals  #p...
# 3  Tonight @Royals  are holding their first ever ...
# 4  Just out here being my self for  Pride  Night ...
#
#                                          url    user_id  usernameTweet
# 0         /Royals/status/1164182907981914113   28603812         Royals
# 1  /RevJeffLukens/status/1164188556128071682   82402389  RevJeffLukens
# 2     /short4cute/status/1169382298984341504  538611232     short4cute
# 3     /DaveDMarko/status/1169388554977533952  239334748     DaveDMarko
# 4         /Lieano/status/1169393795416436736   90693778         Lieano

# %%
#create the new column and give all rows the same value-- this is how we will keep track of the team names
df['team'] = "whitesox"
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1164182907981914113  2019-08-21 10:30:09       NaN     False       False
# 1  1164188556128071682  2019-08-21 10:52:36       NaN      True       False
# 2  1169382298984341504  2019-09-04 18:50:40       NaN     False       False
# 3  1169388554977533952  2019-09-04 19:15:32       NaN     False       False
# 4  1169393795416436736  2019-09-04 19:36:21       NaN     False       False
#
#   medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0    NaN           179         14           29
# 1    NaN            16          2            0
# 2    NaN             1          0            0
# 3    NaN             2          0            0
# 4    NaN             6          1            0
#
#                                                 text  \
# 0  Join us for  Pride  Night at #TheK  on Septemb...
# 1  So glad the @Royals  are finally promoting #Pr...
# 2  @ Royals   Pride  Night at The K #kcroyals  #p...
# 3  Tonight @Royals  are holding their first ever ...
# 4  Just out here being my self for  Pride  Night ...
#
#                                          url    user_id  usernameTweet    team
# 0         /Royals/status/1164182907981914113   28603812         Royals  royals
# 1  /RevJeffLukens/status/1164188556128071682   82402389  RevJeffLukens  royals
# 2     /short4cute/status/1169382298984341504  538611232     short4cute  royals
# 3     /DaveDMarko/status/1169388554977533952  239334748     DaveDMarko  royals
# 4         /Lieano/status/1169393795416436736   90693778         Lieano  royals

# %%
#dump it to a csv so we can use it later

df.to_csv('basic_csv/royals_tweets.csv', index=True)
