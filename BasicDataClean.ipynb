# %% [markdown]
# #### This notebook collects all of the tweets for a given team, imports them into a dataframe, adds a team classification tag, and dumps to a csv.

# %%
#bring in the prerequisites

import pandas as pd
import glob
import json
import numpy as np
import pandas as pd

# %%
# identify the folder where the files are -- this will be done once per team, aligning the team folder name to the column we will create
files = glob.glob('raw_tweets/pride_whitesox/*')
#files = glob.glob('user/*')
len(files)
# Out:
# 114

# %%
#make a list to hold the files we are going to read
#then read the files into a dictionary

dictlist = []

for file in files:
    json_string = open(file, 'r').read()
    json_dict = json.loads(json_string)
    dictlist.append(json_dict)

# %%
#create a dataframe from the dictionary
df = pd.DataFrame(dictlist)
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1005194002482659328  2018-06-08 17:05:00       NaN     False       False
# 1  1008141694179651586  2018-06-16 20:18:04       NaN     False       False
# 2  1016231011275792384  2018-07-09 04:02:08       NaN     False       False
# 3  1016243488738947072  2018-07-09 04:51:43       NaN     False       False
# 4  1016353173370355712  2018-07-09 12:07:34      True     False       False
#
#                       medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0                        NaN             0          0            0
# 1                        NaN             0          0            0
# 2                        NaN             0          0            0
# 3                        NaN             0          0            0
# 4  [https://t.co/45A0VmLzXC]            73          1           13
#
#                                                 text  \
# 0  A big, big THANK YOU to the @RedSox  for hosti...
# 1  Dear @whitesox  as a season ticket holder and ...
# 2  White Sox  to host first  LGBTQ  Pride night a...
# 3  Chcago  White Sox  host first #LGBTQ  Pride ni...
# 4  White Sox  to host team's first LGBTQ #PrideNi...
#
#                                            url             user_id  \
# 0   /Mobhunter_1900/status/1005194002482659328          2803807867
# 1      /NotoriouSvo/status/1008141694179651586            34939027
# 2        /texasfine/status/1016231011275792384          1474634755
# 3  /americanunity40/status/1016243488738947072  938609252884729856
# 4        /outsports/status/1016353173370355712            20458149
#
#      usernameTweet
# 0   Mobhunter_1900
# 1      NotoriouSvo
# 2        texasfine
# 3  americanunity40
# 4        outsports

# %%
#create the new column and give all rows the same value-- this is how we will keep track of the team names
df['team'] = "whitesox"
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1005194002482659328  2018-06-08 17:05:00       NaN     False       False
# 1  1008141694179651586  2018-06-16 20:18:04       NaN     False       False
# 2  1016231011275792384  2018-07-09 04:02:08       NaN     False       False
# 3  1016243488738947072  2018-07-09 04:51:43       NaN     False       False
# 4  1016353173370355712  2018-07-09 12:07:34      True     False       False
#
#                       medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0                        NaN             0          0            0
# 1                        NaN             0          0            0
# 2                        NaN             0          0            0
# 3                        NaN             0          0            0
# 4  [https://t.co/45A0VmLzXC]            73          1           13
#
#                                                 text  \
# 0  A big, big THANK YOU to the @RedSox  for hosti...
# 1  Dear @whitesox  as a season ticket holder and ...
# 2  White Sox  to host first  LGBTQ  Pride night a...
# 3  Chcago  White Sox  host first #LGBTQ  Pride ni...
# 4  White Sox  to host team's first LGBTQ #PrideNi...
#
#                                            url             user_id  \
# 0   /Mobhunter_1900/status/1005194002482659328          2803807867
# 1      /NotoriouSvo/status/1008141694179651586            34939027
# 2        /texasfine/status/1016231011275792384          1474634755
# 3  /americanunity40/status/1016243488738947072  938609252884729856
# 4        /outsports/status/1016353173370355712            20458149
#
#      usernameTweet      team
# 0   Mobhunter_1900  whitesox
# 1      NotoriouSvo  whitesox
# 2        texasfine  whitesox
# 3  americanunity40  whitesox
# 4        outsports  whitesox

# %%
#dump it to a csv so we can use it later

df.to_csv('basic_csv/whitesox_tweets.csv', index=True)
