# %% [markdown]
# #### This notebook collects all of the tweets for a given team, imports them into a dataframe, adds a team classification tag, and dumps to a csv.

# %%
#bring in the prerequisites

import pandas as pd
import glob
import json
import numpy as np
import pandas as pd

# %%
# identify the folder where the files are -- this will be done once per team, aligning the team folder name to the column we will create
files = glob.glob('raw_tweets/pride_phillies/*')
#files = glob.glob('user/*')
len(files)
# Out:
# 155

# %%
#make a list to hold the files we are going to read
#then read the files into a dictionary

dictlist = []

for file in files:
    json_string = open(file, 'r').read()
    json_dict = json.loads(json_string)
    dictlist.append(json_dict)

# %%
#create a dataframe from the dictionary
df = pd.DataFrame(dictlist)
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1134617287699382272  2019-05-31 20:26:56      True     False       False
# 1  1134644069919911937  2019-05-31 22:13:21       NaN     False       False
# 2  1134652413078642688  2019-05-31 22:46:30       NaN      True       False
# 3  1134673571081588736  2019-06-01 00:10:35       NaN     False       False
# 4  1134799775230976000  2019-06-01 08:32:04      True      True       False
#
#                       medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0  [https://t.co/rXWWyQ3Boq]             3          0            1
# 1                        NaN             3          0            0
# 2                        NaN             1          1            0
# 3                        NaN             4         13            0
# 4  [https://t.co/7jWh2x7LsO]             0          0            0
#
#                                                 text  \
# 0  Phillies   Pride   Night  is June 26. Tickets ...
# 1  *At  Pride   Night  at Dodgers/ Phillies  game...
# 2  Yeah, the  Phillies  have been doing a  Pride ...
# 3  2. Do you think  Phillies  fans would be more ...
# 4  Just went to a Dodgers/ Phillies  game in LA o...
#
#                                            url              user_id  \
# 0     /The_Real_Kub/status/1134617287699382272             27953804
# 1   /ColonelKSpeaks/status/1134644069919911937             21708385
# 2  /CPTPhiladelphia/status/1134652413078642688            460121331
# 3      /Chuckles152/status/1134673571081588736             26968843
# 4       /66Vandelay/status/1134799775230976000  1017566376670588928
#
#      usernameTweet
# 0     The_Real_Kub
# 1   ColonelKSpeaks
# 2  CPTPhiladelphia
# 3      Chuckles152
# 4       66Vandelay

# %%
#create the new column and give all rows the same value-- this is how we will keep track of the team names
df['team'] = "phillies"
df.head()
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1134617287699382272  2019-05-31 20:26:56      True     False       False
# 1  1134644069919911937  2019-05-31 22:13:21       NaN     False       False
# 2  1134652413078642688  2019-05-31 22:46:30       NaN      True       False
# 3  1134673571081588736  2019-06-01 00:10:35       NaN     False       False
# 4  1134799775230976000  2019-06-01 08:32:04      True      True       False
#
#                       medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0  [https://t.co/rXWWyQ3Boq]             3          0            1
# 1                        NaN             3          0            0
# 2                        NaN             1          1            0
# 3                        NaN             4         13            0
# 4  [https://t.co/7jWh2x7LsO]             0          0            0
#
#                                                 text  \
# 0  Phillies   Pride   Night  is June 26. Tickets ...
# 1  *At  Pride   Night  at Dodgers/ Phillies  game...
# 2  Yeah, the  Phillies  have been doing a  Pride ...
# 3  2. Do you think  Phillies  fans would be more ...
# 4  Just went to a Dodgers/ Phillies  game in LA o...
#
#                                            url              user_id  \
# 0     /The_Real_Kub/status/1134617287699382272             27953804
# 1   /ColonelKSpeaks/status/1134644069919911937             21708385
# 2  /CPTPhiladelphia/status/1134652413078642688            460121331
# 3      /Chuckles152/status/1134673571081588736             26968843
# 4       /66Vandelay/status/1134799775230976000  1017566376670588928
#
#      usernameTweet      team
# 0     The_Real_Kub  phillies
# 1   ColonelKSpeaks  phillies
# 2  CPTPhiladelphia  phillies
# 3      Chuckles152  phillies
# 4       66Vandelay  phillies

# %%
#dump it to a csv so we can use it later

df.to_csv('basic_csv/phillies_tweets.csv', index=True)
